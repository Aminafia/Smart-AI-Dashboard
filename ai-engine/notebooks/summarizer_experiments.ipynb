# %%
from utils import split_sentences
from inference import simple_summarize

text = "This is sentence one. This is sentence two. This is sentence three."
summary, n = simple_summarize(text)
summary, n
